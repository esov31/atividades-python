# %% [markdown]
# <a href="https://colab.research.google.com/github/esov31/atividades-python/blob/main/Atividade_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Atividade 01 — Introdução ao Python

# %%
print("Minha primeira atividade no Google Colab")
print("Aprendendo Python e GitHub")
# Out:
# Minha primeira atividade no Google Colab
# Aprendendo Python e GitHub

# %%
disciplina = input("Digite o nome da disciplina: ")
conteudo = input("Digite o conteúdo estudado: ")
atividade = input("Digite o número da atividade: ")
print("\n--- Informações da atividade ---")
print("Disciplina:", disciplina)
print("Conteúdo:", conteudo)
print("Atividade:", atividade)
# Out:
# Digite o nome da disciplina: Algoritmos e Lógica da programação
# Digite o conteúdo estudado: Google Colab + GitHub: criando, salvando e versionando um notebook
# Digite o número da atividade: 01
#
# --- Informações da atividade ---
# Disciplina: Algoritmos e Lógica da programação
# Conteúdo: Google Colab + GitHub: criando, salvando e versionando um notebook
# Atividade: 01

# %%
numero1 = 10
numero2 = 20
soma = numero1 + numero2
print("Resultado:", soma)
# Out:
# Resultado: 30
